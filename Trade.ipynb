# %% [markdown]
# #                          ***Trade Analysis***
# #
#
# ### Shania Job
#
#
# In this project I have considered the dataset which deals with trade information for various countries over different timelines. The dataset was then cleaned and visualised. The visualisations provide a backbone to understand the inferences that have been listed.
#
#
# * This project consists of multivariate charts, multidimensional charts, temporal and hierachical data visualisations.
# * All the columns and rows haven't been considered in this analysis for the sake of simplicity.

# %% [markdown]
# #### **Data Sourcing**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express 39.5as px
import plotly.graph_objects as go
import plotly.figure_factory as ff

# Comment this if the data visualisations doesn't work on your side
# %matplotlib inline
plt.style.use('bmh')
sns.set_style('darkgrid')

# %% [markdown]
# Data Sourcing, the first step of Exploratory Data Analysis has been accomplished.
#
# *   Dataset chosen: trade

# %%
dataset_raw_df = pd.read_csv('/content/drive/MyDrive/sampledata/trade.csv')
dataset_raw_df
# Out:
#                                      Country Name  ... Travel services (% of commercial service imports)
# 0                                         Albania  ...                                          0.000000
# 1                                      Azerbaijan  ...                                         35.185066
# 2                                      Azerbaijan  ...                                         30.433028
# 3                                    Burkina Faso  ...                                          0.000000
# 4                                        Bulgaria  ...                                         14.394904
# ...                                           ...  ...                                               ...
# 13594                                     Vietnam  ...                                          0.000000
# 13595                                 Yemen, Rep.  ...                                          0.000000
# 13596                                   IDA blend  ...                                          0.000000
# 13597  Sub-Saharan Africa (excluding high income)  ...                                         27.170802
# 13598                                       Tonga  ...                                          0.000000
#
# [13599 rows x 53 columns]

# %%
# Rows and columns in the dataset
dataset_raw_df.shape
# Out:
# (13599, 53)

# %%
# Columns present in the dataset
dataset_raw_df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Year',
#        'Agricultural raw materials exports (% of merchandise exports)',
#        'Commercial service exports (current US$)',
#        'Commercial service imports (current US$)',
#        'Computer, communications and other services (% of commercial service exports)',
#        'Export value index (2000 = 100)', 'Export volume index (2000 = 100)',
#        'Food exports (% of merchandise exports)',
#        'Fuel exports (% of merchandise exports)',
#        'Fuel imports (% of merchandise imports)',
#        'High-technology exports (% of manufactured exports)',
#        'High-technology exports (current US$)',
#        'ICT goods exports (% of total goods exports)',
#        'ICT goods imports (% total goods imports)',
#        'Import value index (2000 = 100)',
#        'Insurance and financial services (% of commercial service exports)',
#        'Insurance and financial services (% of commercial service imports)',
#        'Manufactures exports (% of merchandise exports)',
#        'Manufactures imports (% of merchandise imports)',
#        'Merchandise exports (current US$)',
#        'Merchandise exports by the reporting economy (current US$)',
#        'Merchandise exports by the reporting economy, residual (% of total merchandise exports)',
#        'Merchandise exports to economies in the Arab World (% of total merchandise exports)',
#        'Merchandise exports to high-income economies (% of total merchandise exports)',
#        'Merchandise exports to low- and middle-income economies in East Asia & Pacific (% of total merchandise exports)',
#        'Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports)',
#        'Merchandise exports to low- and middle-income economies in Latin America & the Caribbean (% of total merchandise exports)',
#        'Merchandise exports to low- and middle-income economies in Middle East & North Africa (% of total merchandise exports)',
#        'Merchandise exports to low- and middle-income economies in South Asia (% of total merchandise exports)',
#        'Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports)',
#        'Merchandise exports to low- and middle-income economies outside region (% of total merchandise exports)',
#        'Merchandise imports (current US$)',
#        'Merchandise imports by the reporting economy (current US$)',
#        'Merchandise imports by the reporting economy, residual (% of total merchandise imports)',
#        'Merchandise imports from economies in the Arab World (% of total merchandise imports)',
#        'Merchandise imports from high-income economies (% of total merchandise imports)',
#        'Merchandise imports from low- and middle-income economies in East Asia & Pacific (% of total merchandise imports)',
#        'Merchandise imports from low- and middle-income economies in Europe & Central Asia (% of total merchandise imports)',
#        'Merchandise imports from low- and middle-income economies in Latin America & the Caribbean (% of total merchandise imports)',
#        'Merchandise imports from low- and middle-income economies in Middle East & North Africa (% of total merchandise imports)',
#        'Merchandise imports from low- and middle-income economies in South Asia (% of total merchandise imports)',
#        'Merchandise imports from low- and middle-income economies in Sub-Saharan Africa (% of total merchandise imports)',
#        'Merchandise imports from low- and middle-income economies outside region (% of total merchandise imports)',
#        'Net barter terms of trade index (2000 = 100)',
#        'Ores and metals exports (% of merchandise exports)',
#        'Ores and metals imports (% of merchandise imports)',
#        'Tariff rate, applied, simple mean, all products (%)',
#        'Transport services (% of commercial service exports)',
#        'Transport services (% of commercial service imports)',
#        'Travel services (% of commercial service exports)',
#        'Travel services (% of commercial service imports)'],
#       dtype='object')

# %%
dataset_raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13599 entries, 0 to 13598
# Data columns (total 53 columns):
#  #   Column                                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                
#  50  Transport services (% of commercial service imports)                                                                         13599 non-null  float64
#  51  Travel services (% of commercial service exports)                                                                            13599 non-null  float64
#  52  Travel services (% of commercial service imports)                                                                            13599 non-null  float64
# dtypes: float64(47), int64(4), object(2)
# memory usage: 5.5+ MB

# %%
# Checking for missing values
dataset_raw_df.isnull().sum()
# Out:
# Country Name                                                                                                                   0
# Country Code                                                                                                                   0
# Year                                                                                                                           0
# Agricultural raw materials exports (% of merchandise exports)                                                                  0
# Commercial service exports (current US$)                                                                                       0
# Commercial service imports (current US$)                                                                                       0
# Computer, communications and other services (% of commercial service exports)                                                  0
# Export value index (2000 = 100)                                                                                                0
# Export volume index (2000 = 100)                                                                                               0
# Food exports (% of merchandise exports)                                                                                        0
# Fuel exports (% of merchandise exports)                                                                                        0
# Fuel imports (% of merchandise imports)                                                                                        0
# High-technology exports (% of manufactured exports)                                                                            0
# High-technology exports (current US$)                                                                                          0
# ICT goods exports (% of total goods exports)                                                                                   0
# ICT goods imports (% total goods imports)                                                                                      0
# Import value index (2000 = 100)                                                                                                0
# Insurance and financial services (% of commercial service exports)                                                             0
# Insurance and financial services (% of commercial service imports)                                                             0
# Manufactures exports (% of merchandise exports)                                                                                0
# Manufactures imports (% of merchandise imports)                                                                                0
# Merchandise exports (current US$)                                                                                              0
# Merchandise exports by the reporting economy (current US$)                                                                     0
# Merchandise exports by the reporting economy, residual (% of total merchandise exports)                                        0
# Merchandise exports to economies in the Arab World (% of total merchandise exports)                                            0
# Merchandise exports to high-income economies (% of total merchandise exports)                                                  0
# Merchandise exports to low- and middle-income economies in East Asia & Pacific (% of total merchandise exports)                0
# Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports)              0
# Merchandise exports to low- and middle-income economies in Latin America & the Caribbean (% of total merchandise exports)      0
# Merchandise exports to low- and middle-income economies in Middle East & North Africa (% of total merchandise exports)         0
# Merchandise exports to low- and middle-income economies in South Asia (% of total merchandise exports)                         0
# Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports)                 0
# Merchandise exports to low- and middle-income economies outside region (% of total merchandise exports)                        0
# Merchandise imports (current US$)                                                                                              0
# Merchandise imports by the reporting economy (current US$)                                                                     0
# Merchandise imports by the reporting economy, residual (% of total merchandise imports)                                        0
# Merchandise imports from economies in the Arab World (% of total merchandise imports)                                          0
# Merchandise imports from high-income economies (% of total merchandise imports)                                                0
# Merchandise imports from low- and middle-income economies in East Asia & Pacific (% of total merchandise imports)              0
# Merchandise imports from low- and middle-income economies in Europe & Central Asia (% of total merchandise imports)            0
# Merchandise imports from low- and middle-income economies in Latin America & the Caribbean (% of total merchandise imports)    0
# Merchandise imports from low- and middle-income economies in Middle East & North Africa (% of total merchandise imports)       0
# Merchandise imports from low- and middle-income economies in South Asia (% of total merchandise imports)                       0
# Merchandise imports from low- and middle-income economies in Sub-Saharan Africa (% of total merchandise imports)               0
# Merchandise imports from low- and middle-income economies outside region (% of total merchandise imports)                      0
# Net barter terms of trade index (2000 = 100)                                                                                   0
# Ores and metals exports (% of merchandise exports)                                                                             0
# Ores and metals imports (% of merchandise imports)                                                                             0
# Tariff rate, applied, simple mean, all products (%)                                                                            0
# Transport services (% of commercial service exports)                                                                           0
# Transport services (% of commercial service imports)                                                                           0
# Travel services (% of commercial service exports)                                                                              0
# Travel services (% of commercial service imports)                                                                              0
# dtype: int64

# %%
# Viewing a sample of 10 entries present in the dataset
dataset_raw_df.sample(10)
# Out:
#       Country Name  ... Travel services (% of commercial service imports)
# 5743     Argentina  ...                                         34.704861
# 1490    Mozambique  ...                                          0.000000
# 12250       Kuwait  ...                                         58.766859
# 10420      Bermuda  ...                                          0.000000
# 1206       Grenada  ...                                         10.553506
# 503          Niger  ...                                         20.998750
# 5629         Japan  ...                                         25.808123
# 7612      Barbados  ...                                         18.991173
# 9415       Jamaica  ...                                          0.000000
# 12649   Tajikistan  ...                                          0.776611
#
# [10 rows x 53 columns]

# %%
dataset_raw_df.describe()
# Out:
#                Year  ...  Travel services (% of commercial service imports)
# count  13599.000000  ...                                       13599.000000
# mean    1989.961615  ...                                          13.721443
# std       16.657786  ...                                          15.828675
# min     1960.000000  ...                                           0.000000
# 25%     1976.000000  ...                                           0.000000
# 50%     1991.000000  ...                                          10.044978
# 75%     2004.000000  ...                                          24.268149
# max     2017.000000  ...                                         182.412624
#
# [8 rows x 51 columns]

# %%
# Checking for duplicate values
duplicate = dataset_raw_df[dataset_raw_df.duplicated()] 
duplicate
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Year, Agricultural raw materials exports (% of merchandise exports), Commercial service exports (current US$), Commercial service imports (current US$), Computer, communications and other services (% of commercial service exports), Export value index (2000 = 100), Export volume index (2000 = 100), Food exports (% of merchandise exports), Fuel exports (% of merchandise exports), Fuel imports (% of merchandise imports), High-technology exports (% of manufactured exports), High-technology exports (current US$), ICT goods exports (% of total goods exports), ICT goods imports (% total goods imports), Import value index (2000 = 100), Insurance and financial services (% of commercial service exports), Insurance and financial services (% of commercial service imports), Manufactures exports (% of merchandise exports), Manufactures imports (% of merchandise imports), Merchandise exports (current US$), Merchandise exports by the reporting economy (current US$), Merchandise exports by the reporting economy, residual (% of total merchandise exports), Merchandise exports to economies in the Arab World (% of total merchandise exports), Merchandise exports to high-income economies (% of total merchandise exports), Merchandise exports to low- and middle-income economies in East Asia & Pacific (% of total merchandise exports), Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports), Merchandise exports to low- and middle-income economies in Latin America & the Caribbean (% of total merchandise exports), Merchandise exports to low- and middle-income economies in Middle East & North Africa (% of total merchandise exports), Merchandise exports to low- and middle-income economies in South Asia (% of total merchandise exports), Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports), Merchandise exports to low- and middle-income economies outside region (% of total merchandise exports), Merchandise imports (current US$), Merchandise imports by the reporting economy (current US$), Merchandise imports by the reporting economy, residual (% of total merchandise imports), Merchandise imports from economies in the Arab World (% of total merchandise imports), Merchandise imports from high-income economies (% of total merchandise imports), Merchandise imports from low- and middle-income economies in East Asia & Pacific (% of total merchandise imports), Merchandise imports from low- and middle-income economies in Europe & Central Asia (% of total merchandise imports), Merchandise imports from low- and middle-income economies in Latin America & the Caribbean (% of total merchandise imports), Merchandise imports from low- and middle-income economies in Middle East & North Africa (% of total merchandise imports), Merchandise imports from low- and middle-income economies in South Asia (% of total merchandise imports), Merchandise imports from low- and middle-income economies in Sub-Saharan Africa (% of total merchandise imports), Merchandise imports from low- and middle-income economies outside region (% of total merchandise imports), Net barter terms of trade index (2000 = 100), Ores and metals exports (% of merchandise exports), Ores and metals imports (% of merchandise imports), Tariff rate, applied, simple mean, all products (%), Transport services (% of commercial service exports), Transport services (% of commercial service imports), Travel services (% of commercial service exports), Travel services (% of commercial service imports)]
# Index: []

# %% [markdown]
# #### **Data Cleaning**
# *So far we can note the following:*
#
#
# *   The absence of NaN values(indicating no missing values are present).
# * The absence of duplicated values.
# *   The presence of complete zero values in many rows(thereby not adding significant value for the analysis). A possible reason for these zero values could be that data wasn't entered for those specific columns/rows.
# * Since the data primarly deals with import/export of various goods(for different countries). Dropping those rows of a column that contain zeroes seems to be more appropriate.
# *   The column names(though comprehendable) are inconvenient(due to white spaces)(while attempting to draw the visualizations).
#
# * Presence of anomalies/outliers will be checked as we investigate further.
#
# *In the next section we attempt to achieve the following:*
# 1. Remove the rows having zero values.
# 2. Altering the column names.

# %%
dataframe = dataset_raw_df

# Renaming the columns
dataframe.columns = [c.replace(' ', '_') for c in dataframe.columns]
dataframe.columns = [c.replace('-', '_') for c in dataframe.columns]
dataframe.columns = [c.replace('%', 'p') for c in dataframe.columns]
dataframe.columns = [c.replace('=', 'p') for c in dataframe.columns]
dataframe.columns = [c.replace('$', 'p') for c in dataframe.columns]
dataframe.columns = [c.replace('&', 'p') for c in dataframe.columns]
dataframe.columns = [c.replace('(', '_') for c in dataframe.columns]
dataframe.columns = [c.replace(')', '_') for c in dataframe.columns]
dataframe.columns = [c.replace('(', '_') for c in dataframe.columns]
dataframe.columns = [c.replace(',', '_') for c in dataframe.columns]


# Removing insignificant/zero values from dataset
# Removes rows having 60% of zero values
dataframe =  dataframe[(~dataframe.astype('bool')).mean(axis=1)<0.6]
# Removes columns having 60% of zero values
dataframe = dataframe.loc[:,(dataframe==0).mean() < 0.6]
dataframe
# Out:
#                                             Country_Name  ... Travel_services__p_of_commercial_service_imports_
# 1                                             Azerbaijan  ...                                         35.185066
# 2                                             Azerbaijan  ...                                         30.433028
# 3                                           Burkina Faso  ...                                          0.000000
# 4                                               Bulgaria  ...                                         14.394904
# 5                                      Brunei Darussalam  ...                                          0.000000
# ...                                                  ...  ...                                               ...
# 13592  Latin America & the Caribbean (IDA & IBRD coun...  ...                                          0.000000
# 13593                     St. Vincent and the Grenadines  ...                                         15.787488
# 13594                                            Vietnam  ...                                          0.000000
# 13596                                          IDA blend  ...                                          0.000000
# 13597         Sub-Saharan Africa (excluding high income)  ...                                         27.170802
#
# [11387 rows x 49 columns]

# %%
dataframe.describe()
# Out:
#                Year  ...  Travel_services__p_of_commercial_service_imports_
# count  11387.000000  ...                                       11387.000000
# mean    1991.667955  ...                                          15.704121
# std       15.934108  ...                                          15.579276
# min     1960.000000  ...                                           0.000000
# 25%     1979.000000  ...                                           0.000000
# 50%     1993.000000  ...                                          14.858194
# 75%     2005.000000  ...                                          25.850894
# max     2017.000000  ...                                         131.025958
#
# [8 rows x 47 columns]

# %%
dataframe.shape
# Out:
# (11387, 49)

# %%
num_of_countries = dataframe.Country_Name.nunique()
num_of_countries
# Out:
# 251

# %%
dataframe.columns
# Out:
# Index(['Country_Name', 'Country_Code', 'Year',
#        'Agricultural_raw_materials_exports__p_of_merchandise_exports_',
#        'Commercial_service_exports__current_USp_',
#        'Commercial_service_imports__current_USp_',
#        'Computer__communications_and_other_services__p_of_commercial_service_exports_',
#        'Export_value_index__2000_p_100_', 'Export_volume_index__2000_p_100_',
#        'Food_exports__p_of_merchandise_exports_',
#        'Fuel_exports__p_of_merchandise_exports_',
#        'Fuel_imports__p_of_merchandise_imports_',
#        'High_technology_exports__p_of_manufactured_exports_',
#        'Import_value_index__2000_p_100_',
#        'Insurance_and_financial_services__p_of_commercial_service_exports_',
#        'Insurance_and_financial_services__p_of_commercial_service_imports_',
#        'Manufactures_exports__p_of_merchandise_exports_',
#        'Manufactures_imports__p_of_merchandise_imports_',
#        'Merchandise_exports__current_USp_',
#        'Merchandise_exports_by_the_reporting_economy__current_USp_',
#        'Merchandise_exports_by_the_reporting_economy__residual__p_of_total_merchandise_exports_',
#        'Merchandise_exports_to_economies_in_the_Arab_World__p_of_total_merchandise_exports_',
#        'Merchandise_exports_to_high_income_economies__p_of_total_merchandise_exports_',
#        'Merchandise_exports_to_low__and_middle_income_economies_in_East_Asia_p_Pacific__p_of_total_merchandise_exports_',
#        'Merchandise_exports_to_low__and_middle_income_economies_in_Europe_p_Central_Asia__p_of_total_merchandise_exports_',
#        'Merchandise_exports_to_low__and_middle_income_economies_in_Latin_America_p_the_Caribbean__p_of_total_merchandise_exports_',
#        'Merchandise_exports_to_low__and_middle_income_economies_in_Middle_East_p_North_Africa__p_of_total_merchandise_exports_',
#        'Merchandise_exports_to_low__and_middle_income_economies_in_South_Asia__p_of_total_merchandise_exports_',
#        'Merchandise_exports_to_low__and_middle_income_economies_in_Sub_Saharan_Africa__p_of_total_merchandise_exports_',
#        'Merchandise_exports_to_low__and_middle_income_economies_outside_region__p_of_total_merchandise_exports_',
#        'Merchandise_imports__current_USp_',
#        'Merchandise_imports_by_the_reporting_economy__current_USp_',
#        'Merchandise_imports_by_the_reporting_economy__residual__p_of_total_merchandise_imports_',
#        'Merchandise_imports_from_economies_in_the_Arab_World__p_of_total_merchandise_imports_',
#        'Merchandise_imports_from_high_income_economies__p_of_total_merchandise_imports_',
#        'Merchandise_imports_from_low__and_middle_income_economies_in_East_Asia_p_Pacific__p_of_total_merchandise_imports_',
#        'Merchandise_imports_from_low__and_middle_income_economies_in_Europe_p_Central_Asia__p_of_total_merchandise_imports_',
#        'Merchandise_imports_from_low__and_middle_income_economies_in_Latin_America_p_the_Caribbean__p_of_total_merchandise_imports_',
#        'Merchandise_imports_from_low__and_middle_income_economies_in_Middle_East_p_North_Africa__p_of_total_merchandise_imports_',
#        'Merchandise_imports_from_low__and_middle_income_economies_in_South_Asia__p_of_total_merchandise_imports_',
#        'Merchandise_imports_from_low__and_middle_income_economies_in_Sub_Saharan_Africa__p_of_total_merchandise_imports_',
#        'Merchandise_imports_from_low__and_middle_income_economies_outside_region__p_of_total_merchandise_imports_',
#        'Net_barter_terms_of_trade_index__2000_p_100_',
#        'Ores_and_metals_exports__p_of_merchandise_exports_',
#        'Ores_and_metals_imports__p_of_merchandise_imports_',
#        'Transport_services__p_of_commercial_service_exports_',
#        'Transport_services__p_of_commercial_service_imports_',
#        'Travel_services__p_of_commercial_service_exports_',
#        'Travel_services__p_of_commercial_service_imports_'],
#       dtype='object')

# %% [markdown]
# We have removed the rows and columns having more than 60% of zero values. Our dataset has reduced from 13599 rows, 53 columns to 11387 rows and 49 columns. We can see the data for 251 countries are present and the data for these countries have been collected over a span of time(this explains the large number of rows in our dataset).

# %% [markdown]
# #### **Data Visualisations**
# In this section we try to dive deeper into our dataset and understand the data clearly with the help of visualisations.

# %%
# 1 Agricultural export percentage vs Ores & metal export percentage in United States over time using bubble charts.

data_1 = dataframe
Country = data_1.Country_Name == "United States"
data_1 = data_1[Country]
data_1 = data_1[data_1.Agricultural_raw_materials_exports__p_of_merchandise_exports_ != 0]
data_1 = data_1[data_1.Ores_and_metals_exports__p_of_merchandise_exports_ != 0]
data_1 = data_1[data_1.Export_value_index__2000_p_100_ != 0]

fig_1 = px.scatter(data_1, x="Agricultural_raw_materials_exports__p_of_merchandise_exports_",
                           y="Ores_and_metals_exports__p_of_merchandise_exports_",
                           size='Export_value_index__2000_p_100_', 
                           color="Year",
                           labels = {
                                    'Agricultural_raw_materials_exports__p_of_merchandise_exports_' : 'Agricultural raw material exports',
                                    'Ores_and_metals_exports__p_of_merchandise_exports_' : 'Ores & metal exports'
                                  },
                          title = "Agricultural export percentage vs Ores & metal export percentage in United States")
fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="2182a6cf-0ec2-41d9-87fa-05f2be6584b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2182a6cf-0ec2-41d9-87fa-05f2be6584b0")) {                    Plotly.newPlot(                        "2182a6cf-0ec2-41d9-87fa-05f2be6584b0",                        [{"hovertemplate": "Agricultural raw material exports=%{x}<br>Ores & metal exports=%{y}<br>Export_value_index__2000_p_100_=%{marker.size}<br>Year=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [2004, 2005, 2014, 1980, 1998, 1986, 2011, 2016, 1983, 1984, 2000, 2001, 1988, 1991, 2012, 1990, 1982, 2008, 1987, 2009, 2003, 2002, 1992, 1994, 2015, 1993, 1999, 1989, 1996, 2010, 1997, 2013, 1981, 1995, 2007, 2006, 1985], "coloraxis": "coloraxis", "size": [104.2148921, 115.2399612, 207.25087539999998, 62.75100546, 87.23907109999999, 36.77922686, 189.5989093, 186.0306196, 28.97139141, 30.83060327, 100.0, 93.24507173, 48.86304831, 60.40394803, 197.6809589, 119.01709186, 29.25160157, 164.6517921, 42.85409537, 135.058024, 92.69143312, 88.64139206, 64.15912023, 71.25175228, 192.16493290000003, 63.13346529, 88.98592947, 52.05480024, 79.94099125, 163.5075545, 88.13993283, 202.0151602, 30.85024263, 74.78316141, 146.8439146, 131.2115848, 31.82655595], "sizemode": "area", "sizeref": 0.5181271885, "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2.6580401958461697, 2.55233824333349, 2.29872686787914, 10.25440138138676, 2.34992230941119, 4.281799448257339, 2.79712181285441, 2.30088486203591, 4.395704635099141, 4.722805916771059, 2.27436473896588, 2.30596029120205, 4.72267658078413, 3.8528227002920894, 2.45470224451183, 8.86295764337142, 4.25196860479809, 2.2873311582933398, 4.77179172248982, 2.31243891638634, 2.63783757436354, 2.40225978264502, 3.6329712642535097, 3.4890543786924, 2.26823068839742, 3.33442751470904, 2.0770637608699096, 4.51317729856183, 3.0726775637365096, 2.6312465253450803, 2.67219583271158, 2.4192466727992405, 4.29274907903773, 3.8628700773979103, 2.41116911266604, 2.46440382338985, 4.23721104228793], "xaxis": "x", "y": [2.4483708463262595, 2.8519358159727104, 3.1851431218735202, 10.2082902158487, 1.93237887302846, 2.6555660309349, 4.205142959860391, 2.75594739000411, 2.87969206840239, 2.8797162168069397, 1.90611046282081, 1.96221250494438, 3.0103077498665, 2.7762280400745296, 3.68995668546946, 6.10632464960604, 2.7254445504212006, 4.12707360367677, 2.5538420400135697, 3.5313200011305397, 2.06699030333168, 1.9653391731332701, 2.3262720270914903, 2.1962893653962703, 2.93606036085465, 2.13402800640779, 1.7995878841871298, 3.2153333712569903, 2.22183568502024, 4.0862289816124, 2.14130978562644, 3.36394091573471, 3.0525547373047597, 2.66821760657544, 3.87277175009714, 3.6186600721542996, 2.8150600667662298], "yaxis": "y"}],                        {"coloraxis": {"colorbar": {"title": {"text": "Year"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a ...

# %% [markdown]
# ####**Terms:**
# * Agricultural raw materials comprises of (crude materials except fuels) (crude fertilizers and minerals excluding coal, petroleum, and precious stones), and 28 (metalliferous ores and scrap).
# * Ores and metals comprises of 27 (crude fertilizer, minerals nes); 28 (metalliferous ores, scrap); and 68 (non-ferrous metals).
# * Export values are the ***current value of exports*** (f.o.b.) converted to US dollars and expressed as a percentage of the average for the base period.
# * Current value of exports is the value for your export goods in currency.
#
# ####**Observations:**
# * This bubble chart plots two variables i.e. Agricultural raw material exports vs Ore & metal exports for USA. The size of the bubble is indicated by the export value index.
# * Over the years from 1980-2000 we see that there is a slight linear relationship between the two goods(agricultural raw materials and ores & metals) being exported. We see in those years agricutural raw materials exporting percentages were slightly higher than that of ores and metals.
# * The years following 2000 an interesting observation can be made i.e. the exporting percentages of ore and metal have surpassed agricultural raw materials.
# * The next aspect is the size of the bubbles, the export value index. One factor contributing to the economy is the export and import indices. In this graph we see that in USA the export value index was considerably small in 1980s to 1985. This implies that economy of USA during this period was weak. A small export value index could either mean that demand for these goods has decreased, but in the case of USA, the country had suffered a severe recession during this period of time resulting in decline of exports which in turn explains the small export value index.
# * However over a period of time we see the economy of USA has improved(indicated by the increase in the export value index over time).

# %%
# 2 Scatter plot matrix(Sample data considered).

data_2 = dataframe
# There are few rows that have zero values. Since the export and import value index are different for different countries.
# It seems most appropriate to delete those rows having zero values.
data_2 = data_2[data_2.Export_value_index__2000_p_100_ != 0]
data_2 = data_2[data_2.Import_value_index__2000_p_100_ != 0]
data_2 = data_2[data_2.Merchandise_exports__current_USp_ != 0]
data_2 = data_2[data_2.Merchandise_imports__current_USp_ != 0]
data_2 = data_2[15:35]

fig_2 = px.scatter_matrix(data_2,
                          dimensions=["Export_value_index__2000_p_100_", "Import_value_index__2000_p_100_","Merchandise_imports__current_USp_", "Merchandise_exports__current_USp_"],
                          color="Country_Name",
                          title="Scatterplot matrix",
                          labels={col:col.replace('_', ' ') for col in data_2.columns})
fig_2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="358b2a15-1a80-4a7a-83f7-41fe5d9f0a8a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("358b2a15-1a80-4a7a-83f7-41fe5d9f0a8a")) {                    Plotly.newPlot(                        "358b2a15-1a80-4a7a-83f7-41fe5d9f0a8a",                        [{"dimensions": [{"axis": {"matches": true}, "label": "Export value index  2000 p 100 ", "values": [235.0581534]}, {"axis": {"matches": true}, "label": "Import value index  2000 p 100 ", "values": [277.294174]}, {"axis": {"matches": true}, "label": "Merchandise imports  current USp ", "values": [142870000000.0]}, {"axis": {"matches": true}, "label": "Merchandise exports  current USp ", "values": [99616000000.0]}], "hovertemplate": "Country Name=India<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>", "legendgroup": "India", "marker": {"color": "#636efa", "symbol": "circle"}, "name": "India", "showlegend": true, "type": "splom"}, {"dimensions": [{"axis": {"matches": true}, "label": "Export value index  2000 p 100 ", "values": [2.5141969619999998]}, {"axis": {"matches": true}, "label": "Import value index  2000 p 100 ", "values": [4.5053795580000005]}, {"axis": {"matches": true}, "label": "Merchandise imports  current USp ", "values": [870000000.0]}, {"axis": {"matches": true}, "label": "Merchandise exports  current USp ", "values": [560000000.0]}], "hovertemplate": "Country Name=Iraq<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>", "legendgroup": "Iraq", "marker": {"color": "#EF553B", "symbol": "circle"}, "name": "Iraq", "showlegend": true, "type": "splom"}, {"dimensions": [{"axis": {"matches": true}, "label": "Export value index  2000 p 100 ", "values": [212.0964712]}, {"axis": {"matches": true}, "label": "Import value index  2000 p 100 ", "values": [198.6448549]}, {"axis": {"matches": true}, "label": "Merchandise imports  current USp ", "values": [74861300000.0]}, {"axis": {"matches": true}, "label": "Merchandise exports  current USp ", "values": [66607200000.0]}], "hovertemplate": "Country Name=Israel<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>", "legendgroup": "Israel", "marker": {"color": "#00cc96", "symbol": "circle"}, "name": "Israel", "showlegend": true, "type": "splom"}, {"dimensions": [{"axis": {"matches": true}, "label": "Export value index  2000 p 100 ", "values": [91.09254211]}, {"axis": {"matches": true}, "label": "Import value index  2000 p 100 ", "values": [110.21245149999999]}, {"axis": {"matches": true}, "label": "Merchandise imports  current USp ", "values": [3638620000.0]}, {"axis": {"matches": true}, "label": "Merchandise exports  current USp ", "values": [1179530000.0]}], "hovertemplate": "Country Name=Jamaica<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>", "legendgroup": "Jamaica", "marker": {"color": "#ab63fa", "symbol": "circle"}, "name": "Jamaica", "showlegend": true, "type": "splom"}, {"dimensions": [{"axis": {"matches": true}, "label": "Export value index  2000 p 100 ", "values": [52.97041921]}, {"axis": {"matches": true}, "label": "Import value index  2000 p 100 ", "values": [54.96634345]}, {"axis": {"matches": true}, "label": "Merchandise imports  current USp ", "values": [1064000000.0]}, {"axis": {"matches": true}, "label": "Merchandise exports  current USp ", "values": [736000000.0]}], "hovertemplate": "Country Name=Cambodia<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>", "legendgroup": "Cambodia", "marker": {"color": "#FFA15A", "symbol": "circle"}, "name": "Cambodia", "showlegend": true, "type": "splom"}, {"dimensions": [{"axis": {"matches": true}, "label": "Export value index  2000 p 100 ", "values": [185.8296214]}, {"axis": {"matches":  ...

# %% [markdown]
# ####**Observations:**
# * An economy is good if the export value index is greater than the it's important value index(as the country is able to obtain a good source of income through trade).Merchandise exports are the products—goods sent out of a country. Merchandise imports are goods brought into a country. It is measured in US dollars. If the Merchandise exports are greater than the imports it suggests that the economy is good.
# * A high merchandise export and a low merchandise import as well as high merchandise export and high export value index contribute to increase in the growth of the economy.
# * A low merchandise export but high values of merchandise import and import value index suggest that the growth of the economy is negative.
# Using the scatter plot matrix and using the above ideas we can classify the economies of various countries as poor(eg. Cambodia, Kiriribati) or good(eg.Netherlands).
# * The availability and abundance of resources, supply and demand play significant roles in the values of these paramters. For instance Netherlands exports machinery , transport equipment ,chemicals, food and livestock etc. and Cambodia imports fabrics, vehicles, medicine etc. (which are essential in our day to day lives).

# %%
# Checking for outliers and removing if outliers are present 
test = dataframe
Q1 = test.quantile(0.25)
Q3 = test.quantile(0.75)
IQR = Q3 - Q1
#print(IQR)

#print(test < (Q1 - 1.5 * IQR)) |(test > (Q3 + 1.5 * IQR))
# Removes the outliers from the dataset
data_new = test[~((test < (Q1 - 1.5 * IQR)) |(test > (Q3 + 1.5 * IQR))).any(axis=1)]
data_new.shape
# Out:
# (1071, 49)

# %%
data_new.columns
# Out:
# Index(['Country_Name', 'Country_Code', 'Year',
#        'Agricultural_raw_materials_exports__p_of_merchandise_exports_',
#        'Commercial_service_exports__current_USp_',
#        'Commercial_service_imports__current_USp_',
#        'Computer__communications_and_other_services__p_of_commercial_service_exports_',
#        'Export_value_index__2000_p_100_', 'Export_volume_index__2000_p_100_',
#        'Food_exports__p_of_merchandise_exports_',
#        'Fuel_exports__p_of_merchandise_exports_',
#        'Fuel_imports__p_of_merchandise_imports_',
#        'High_technology_exports__p_of_manufactured_exports_',
#        'Import_value_index__2000_p_100_',
#        'Insurance_and_financial_services__p_of_commercial_service_exports_',
#        'Insurance_and_financial_services__p_of_commercial_service_imports_',
#        'Manufactures_exports__p_of_merchandise_exports_',
#        'Manufactures_imports__p_of_merchandise_imports_',
#        'Merchandise_exports__current_USp_',
#        'Merchandise_exports_by_the_reporting_economy__current_USp_',
#        'Merchandise_exports_by_the_reporting_economy__residual__p_of_total_merchandise_exports_',
#        'Merchandise_exports_to_economies_in_the_Arab_World__p_of_total_merchandise_exports_',
#        'Merchandise_exports_to_high_income_economies__p_of_total_merchandise_exports_',
#        'Merchandise_exports_to_low__and_middle_income_economies_in_East_Asia_p_Pacific__p_of_total_merchandise_exports_',
#        'Merchandise_exports_to_low__and_middle_income_economies_in_Europe_p_Central_Asia__p_of_total_merchandise_exports_',
#        'Merchandise_exports_to_low__and_middle_income_economies_in_Latin_America_p_the_Caribbean__p_of_total_merchandise_exports_',
#        'Merchandise_exports_to_low__and_middle_income_economies_in_Middle_East_p_North_Africa__p_of_total_merchandise_exports_',
#        'Merchandise_exports_to_low__and_middle_income_economies_in_South_Asia__p_of_total_merchandise_exports_',
#        'Merchandise_exports_to_low__and_middle_income_economies_in_Sub_Saharan_Africa__p_of_total_merchandise_exports_',
#        'Merchandise_exports_to_low__and_middle_income_economies_outside_region__p_of_total_merchandise_exports_',
#        'Merchandise_imports__current_USp_',
#        'Merchandise_imports_by_the_reporting_economy__current_USp_',
#        'Merchandise_imports_by_the_reporting_economy__residual__p_of_total_merchandise_imports_',
#        'Merchandise_imports_from_economies_in_the_Arab_World__p_of_total_merchandise_imports_',
#        'Merchandise_imports_from_high_income_economies__p_of_total_merchandise_imports_',
#        'Merchandise_imports_from_low__and_middle_income_economies_in_East_Asia_p_Pacific__p_of_total_merchandise_imports_',
#        'Merchandise_imports_from_low__and_middle_income_economies_in_Europe_p_Central_Asia__p_of_total_merchandise_imports_',
#        'Merchandise_imports_from_low__and_middle_income_economies_in_Latin_America_p_the_Caribbean__p_of_total_merchandise_imports_',
#        'Merchandise_imports_from_low__and_middle_income_economies_in_Middle_East_p_North_Africa__p_of_total_merchandise_imports_',
#        'Merchandise_imports_from_low__and_middle_income_economies_in_South_Asia__p_of_total_merchandise_imports_',
#        'Merchandise_imports_from_low__and_middle_income_economies_in_Sub_Saharan_Africa__p_of_total_merchandise_imports_',
#        'Merchandise_imports_from_low__and_middle_income_economies_outside_region__p_of_total_merchandise_imports_',
#        'Net_barter_terms_of_trade_index__2000_p_100_',
#        'Ores_and_metals_exports__p_of_merchandise_exports_',
#        'Ores_and_metals_imports__p_of_merchandise_imports_',
#        'Transport_services__p_of_commercial_service_exports_',
#        'Transport_services__p_of_commercial_service_imports_',
#        'Travel_services__p_of_commercial_service_exports_',
#        'Travel_services__p_of_commercial_service_imports_'],
#       dtype='object')

# %%
# 3 Parallel sets.

data_3 = data_new
data_3 = data_3[data_3.Export_value_index__2000_p_100_ != 0]
data_3 = data_3[data_3.Insurance_and_financial_services__p_of_commercial_service_exports_ != 0]
data_3 = data_3.sort_values(by=['Year'])
data_3 = data_3.tail(10)

fig_3 = px.parallel_categories(data_3, dimensions=['Year','Country_Name','Insurance_and_financial_services__p_of_commercial_service_exports_','Export_value_index__2000_p_100_'],
                               color = 'Year', color_continuous_scale=px.colors.sequential.Inferno,
                               labels = {'Year' : 'Year','Country_Name' : 'Country','Insurance_and_financial_services__p_of_commercial_service_exports_' : 'Insurance and financial services exports %','Export_value_index__2000_p_100_' : 'Export value index'})
fig_3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="2f5c7b84-79f2-43d1-ae2a-fcd34818a722" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f5c7b84-79f2-43d1-ae2a-fcd34818a722")) {                    Plotly.newPlot(                        "2f5c7b84-79f2-43d1-ae2a-fcd34818a722",                        [{"dimensions": [{"label": "Year", "values": [2009, 2010, 2010, 2011, 2011, 2012, 2013, 2014, 2015, 2016]}, {"label": "Country", "values": ["Palau", "Faroe Islands", "Palau", "Faroe Islands", "Palau", "St. Kitts and Nevis", "Palau", "West Bank and Gaza", "St. Kitts and Nevis", "Antigua and Barbuda"]}, {"label": "Insurance and financial services exports %", "values": [0.6551729013558729, 0.7321765109755641, 0.6834289005138672, 0.7779128364492389, 0.563332943922052, 0.915345940375326, 0.538626146052778, 0.021230700359936003, 5.60979827093284, 4.05819316712987]}, {"label": "Export value index", "values": [52.13764338, 176.9964135, 52.13764338, 212.59156119999997, 52.13764338, 141.19097969999999, 60.82725061, 274.0895425, 172.3389375, 150.3917379]}], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "line": {"color": [2009, 2010, 2010, 2011, 2011, 2012, 2013, 2014, 2015, 2016], "coloraxis": "coloraxis"}, "name": "", "type": "parcats"}],                        {"coloraxis": {"colorbar": {"title": {"text": "Year"}}, "colorscale": [[0.0, "#000004"], [0.1111111111111111, "#1b0c41"], [0.2222222222222222, "#4a0c6b"], [0.3333333333333333, "#781c6d"], [0.4444444444444444, "#a52c60"], [0.5555555555555556, "#cf4446"], [0.6666666666666666, "#ed6925"], [0.7777777777777778, "#fb9b06"], [0.8888888888888888, "#f7d13d"], [1.0, "#fcffa4"]]}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorba ...

# %% [markdown]
# ####**Observations:**
# * The parallel sets is a visualization of multi-dimensional categorical data sets. Each variable in the data set is represented by a column of rectangles, where each rectangle corresponds to a value taken on by that variable.The relative heights of the rectangles reflect the relative frequency of occurrence of the corresponding value.
# * In this parallel set we see that in the year 2010 and 2011 the corresponding data for two different countries are present respectively. Under the Country rectangle we see that it has the highest frequency indicated by height of it's rectangle. The export value index for Palau has been the same value for the years 2009-2011(indicates no growth in economy during this period)(Stagnant export value indices can arise as a result of inflation, financial bubble burst all factors that contriute to a poor economy).

# %%
# 3 Parallel sets(large sample).

data_3 = data_new
data_3 = data_3[data_3.Export_value_index__2000_p_100_ != 0]
data_3 = data_3[data_3.Insurance_and_financial_services__p_of_commercial_service_exports_ != 0]
data_3 = data_3.sort_values(by=['Year'])
data_3_2 = data_3.tail(40)

fig_3_2 = px.parallel_categories(data_3_2, dimensions=['Year', 'Country_Name', 'Insurance_and_financial_services__p_of_commercial_service_exports_','Export_value_index__2000_p_100_'],
                color="Year", color_continuous_scale=px.colors.sequential.Inferno,
                labels={'Year':'Year',
                        'Country_Name':'Country', 
                        'Insurance_and_financial_services__p_of_commercial_service_exports_':'Insurance and financial services export %',
                        'Export_value_index__2000_p_100_' : 'Export value index'
                        })
fig_3_2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id
}}, "colorscale": [[0.0, "#000004"], [0.1111111111111111, "#1b0c41"], [0.2222222222222222, "#4a0c6b"], [0.3333333333333333, "#781c6d"], [0.4444444444444444, "#a52c60"], [0.5555555555555556, "#cf4446"], [0.6666666666666666, "#ed6925"], [0.7777777777777778, "#fb9b06"], [0.8888888888888888, "#f7d13d"], [1.0, "#fcffa4"]]}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type ...

# %%
# 4 Transport service percentage of various countries over a period of time using heat map.

plt.subplots(figsize=(14,7))
data_4 = dataframe[dataframe.Transport_services__p_of_commercial_service_exports_ != 0]

plt.title('Transport service percentage of various countries over a period of time ');
data_4 = data_4.pivot('Year','Country_Name','Transport_services__p_of_commercial_service_exports_')
fig_4 = sns.heatmap(data_4,cmap = "mako")

# %% [markdown]
# ####**Observations:**
# * From the above heatmap, the range of export percentages are from negative to positive values. A negative value indicates the importing percentage is greater than exporting percentage. In this graph negative values arises in the years ranging from 1980 to 2000(few values haven't been entered as well).
# * Transport services (% of commercial service exports) covers all transport services (sea, air, land, internal waterway, space, and pipeline) performed by residents of one economy for those of another and involving the carriage of passengers, movement of goods (freight), rental of carriers with crew, and related support and auxiliary services.
# * Over time we can see that the percentages have increased. A reason for this could be due to the increase in tourism,availabiltity of fuel resources, advancement in technology, vehicles and equipment over the passage of time.

# %%
# 5  Trends in Merchandise exports using sparklines.

data_5 = dataframe
data_5 = data_5[data_5.Merchandise_exports_to_high_income_economies__p_of_total_merchandise_exports_ != 0]
data_5 = data_5[['Country_Name', 'Year', 'Merchandise_exports_to_high_income_economies__p_of_total_merchandise_exports_']]

fig = px.line(data_5, y = 'Merchandise_exports_to_high_income_economies__p_of_total_merchandise_exports_', line_group = 'Year', color = 'Year')

# hide and lock down axes
fig.update_xaxes(visible=False, fixedrange=True)
fig.update_yaxes(visible=False, fixedrange=True)

# remove facet/subplot labels
fig.update_layout(annotations=[], overwrite=True)

# strip down the rest of the plot
fig.update_layout(
    showlegend=False,
    plot_bgcolor="white",
    margin=dict(t=10,l=10,b=10,r=10)
)

# disable the modebar for such a small plot
fig.show(config=dict(displayModeBar=False))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="069008c4-7ffc-4840-a614-806d7c533e36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("069008c4-7ffc-4840-a614-806d7c533e36")) {                    Plotly.newPlot(                        "069008c4-7ffc-4840-a614-806d7c533e36",                        [{"hovertemplate": "Year=2013<br>index=%{x}<br>Merchandise_exports_to_high_income_economies__p_of_total_merchandise_exports_=%{y}<extra></extra>", "legendgroup": "2013", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "2013", "showlegend": true, "type": "scattergl", "x": [1, 27, 32, 35, 171, 217, 254, 362, 408, 440, 594, 647, 652, 699, 715, 795, 826, 919, 920, 922, 960, 1002, 1008, 1059, 1084, 1097, 1134, 1181, 1218, 1310, 1314, 1340, 1391, 1432, 1443, 1446, 1449, 1472, 1527, 1554, 1635, 1672, 1675, 1692, 1711, 1785, 1864, 1904, 1929, 1954, 2005, 2327, 2334, 2357, 2397, 2401, 2496, 2550, 2587, 2592, 2716, 2741, 2764, 2854, 2872, 3095, 3110, 3222, 3332, 3345, 3436, 3450, 3497, 3499, 3607, 3612, 3617, 3622, 3660, 3668, 3871, 3882, 3944, 3957, 4034, 4112, 4189, 4272, 4355, 4379, 4576, 4595, 4615, 4732, 4786, 4875, 4893, 4946, 4981, 5061, 5086, 5136, 5145, 5210, 5472, 5729, 5819, 5917, 5936, 6019, 6026, 6031, 6098, 6233, 6269, 6297, 6342, 6370, 6454, 6461, 6494, 6543, 6588, 6691, 6826, 6915, 6929, 6979, 7178, 7190, 7247, 7260, 7266, 7339, 7350, 7365, 7435, 7464, 7472, 7479, 7644, 7676,
# 13594                                            Vietnam  ...                                          74.687445
# 13596                                          IDA blend  ...                                         152.641600
# 13597         Sub-Saharan Africa (excluding high income)  ...                                          65.073332
#
# [11255 rows x 3 columns]

# %% [markdown]
# ####**Observations:**
#
# * Merchandise exports to high-income economies are the sum of merchandise exports from the reporting economy to high-income economies according to the World Bank classification of economies. Data are expressed as a percentage of total merchandise exports by the economy.
# * Sparklines are used to visualize the data trend over time. In the sparkline drawn above different colours specify different years.
# * A peak corresponds to high merchandise export to high income economies(equivalent to saying more profit through export) and a fall represents a loss after exporting to high income economies.
# * For a given year(line) each point on the line corresponds to the country(identified by it's index).With this we can identify those countries having maximum(peaks) and minimum(fall) merchandise exports to high economies percentages.

# %%
# 6 Trends in High Technology, Computer Communication, Ores & metals export percentages in India using stream graphs.

plt.figure(figsize=(22,12))

data_6 = dataframe
country_6 = data_6.Country_Name == "India"
data_6 = data_6[country_6]
#data_6 = data_6.sort_values(by=['Year'])
data_6 = data_6[data_6.High_technology_exports__p_of_manufactured_exports_ != 0]
data_6 = data_6[data_6.Computer__communications_and_other_services__p_of_commercial_service_exports_ != 0]
data_6 = data_6[data_6.Ores_and_metals_exports__p_of_merchandise_exports_!= 0]
data_6 = data_6[['Ores_and_metals_exports__p_of_merchandise_exports_','High_technology_exports__p_of_manufactured_exports_','Computer__communications_and_other_services__p_of_commercial_service_exports_',]]
# blue - Ores and metal exports
# red - High technology exports
# violet - Computer and communication exports
data_6 = data_6.tail(25)
#data_6 (record starts from the year 1993)
data_6 = data_6.to_numpy()
fig, ax = plt.subplots()
ax.stackplot(range(25), data_6.T, baseline='wiggle')
plt.title("Trends in High Technology, Computer Communication, Ores & metals export percentages in India")
plt.show()

# %% [markdown]
# ####**Observations:**
# * Stream graphs are often used to show changes of different categories over time. The height of each individual stream shape shows how the value of that stream has changed over time. The length of the stream shape shows its duration. Colours have been used to differentiate between different categories.
# * blue - Ores and metal exports,
#   red - High technology exports,
#   violet - Computer and communication exports
# * From this we can see over time India's computer and communication export percentage has increased significantly(peaks in the graph). We can say that international telecommunications, the postal and courier serivices, computer data etc. provided by India are widely exported(indicating demand for these services from other countries).
# * High technology goods include products with high R&D intensity, such as in aerospace, computers, pharmaceuticals, scientific instruments, and electrical machinery. Over time we can see a slight decrease in the export percentages of these goods suggesting that countries seek demand for these products from more developed countries(as exposure to high technology is a paramter in indicating the development of an economy).
# * The product with a small export percentage in India goes to the ores and metals. We can see a decline in the export percentages over time.

# %%
# Stream graphs (plot 2)
rb = dataframe
rb = rb[['Net_barter_terms_of_trade_index__2000_p_100_','Manufactures_imports__p_of_merchandise_imports_','Manufactures_exports__p_of_merchandise_exports_']]
rb = rb.head(100)
rb = rb.to_numpy()
fig, ax = plt.subplots()
ax.stackplot(range(100), rb.T, baseline = 'wiggle')
plt.show()

# %% [markdown]
#  This stream graph displays the trend of manufacture exports, manufacture imports and net barter terms of trade index(ratio of export value index to import value index).
#  * blue - Net barter terms of trade index
#  * red - Manufacture imports %
#  * violet - Manufacture exports %

# %%
# 7 Manufacture export/import percentages around the world using stacked bar charts.

plt.figure(figsize=(22,12))

data_7 = dataframe[['Manufactures_exports__p_of_merchandise_exports_','Manufactures_imports__p_of_merchandise_imports_','Country_Name' ]]
data_7 = data_7[data_7.Manufactures_imports__p_of_merchandise_imports_ != 0]
data_7 = data_7[data_7.Manufactures_exports__p_of_merchandise_exports_ != 0]
data_7 = data_7[71:85];

plt.bar(data_7.Country_Name, data_7.Manufactures_imports__p_of_merchandise_imports_);
plt.bar(data_7.Country_Name, data_7.Manufactures_exports__p_of_merchandise_exports_);
plt.legend(['Manufacture import %', 'Manufacture export %']);
plt.xlabel('Countries');
plt.title("Manufacture export/import percentages around the world");

# %% [markdown]
# ####**Observations:**
# In this stacked barchart, we see that countries half of the countries have more manufacture export % suggesting these countries have good economies(eg. Austria). Few countries have extremely high import %s (eg. Vanuatu and Malawi). Countries like Vanuatu have economies which are solely dependent on agriculture and tourism which explains the greater percentage in manufacture imports. Countries like Austria are much more advanced in technology and export machinery, equipment and other manufactured goods. In Singapore we see a very small gap between the 2 percentages therefore suggesting very good potential in it's economic growth.

# %%
# 8 Tree maps.

data_8 = dataframe
data_8 = data_8[data_8.Net_barter_terms_of_trade_index__2000_p_100_ != 0 ]

fig_8 = px.treemap(data_8, path=['Year','Country_Name','Net_barter_terms_of_trade_index__2000_p_100_'],
                   values='Merchandise_exports_by_the_reporting_economy__current_USp_',
                   color='Export_value_index__2000_p_100_',hover_data=['Export_volume_index__2000_p_100_'],
                   color_continuous_midpoint=np.average(data_8['Export_value_index__2000_p_100_'], weights=data_8['Merchandise_exports_by_the_reporting_economy__current_USp_'])
                   )
fig_8.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="47a48805-3dcd-4002-ba9f-7938e1761f10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47a48805-3dcd-4002-ba9f-7938e1761f10")) {                    Plotly.newPlot(                        "47a48805-3dcd-4002-ba9f-7938e1761f10",                        [{"branchvalues": "total", "customdata": [[256.791542, 181.1900102], [259.0790482, 164.13555730000002], [198.6338886, 164.9589798], [201.0029075, 117.2004732], [7.718816852000001, 5.171607291], [4.256843319, 3.4054746560000004], [16.39974833, 11.62078396], [65.47937859, 45.16800365], [12.84758517, 5.652937475], [76.97042219, 40.01823154], [25.78330278, 21.12579763], [168.8813362, 97.98728087000002], [5.037115179, 4.583774813], [112.13982890000001, 54.9513861], [4.973643832, 3.8297057510000005], [348.0358003, 215.78219620000002], [5.120552837, 4.506086497], [263.1040461, 181.5417918], [334.9514563, 212.3168071], [4429.294134000001, 3926.0541079999994], [287.3786408, 182.91523490000003], [124.6153136, 46.98402861], [3.42131603, 2.223855419], [104.021389, 44.72755965], [223.78640780000003, 132.20581], [280.8252427, 191.1569137], [242.7184466, 147.432579], [292.60929469999996, 222.3830639], [285.19417480000004, 154.02291359999998], [229.36893199999997, 146.5748455], [245.14563109999997, 140.17509030000002], [189.0776699, 99.63535116999999], [5.13112183, 3.6944077180000003], [5267.423000000001, 4
.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="643300fe-d847-4b28-9a68-2205ce986d8a" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("643300fe-d847-4b28-9a68-2205ce986d8a")) {                    Plotly.newPlot(                        "643300fe-d847-4b28-9a68-2205ce986d8a",                        [{"hoverinfo": "text", "marker": {"color": "rgb(0,116,217)"}, "mode": "lines", "type": "scatter", "x": [5.0, 5.0, 15.0, 15.0], "xaxis": "x", "y": [0.0, 3.451963454669945, 3.451963454669945, 0.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(0,116,217)"}, "mode": "lines", "type": "scatter", "x": [25.0, 25.0, 35.0, 35.0], "xaxis": "x", "y": [0.0, 5.396972119062367, 5.396972119062367, 0.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(0,116,217)"}, "mode": "lines", "type": "scatter", "x": [10.0, 10.0, 30.0, 30.0], "xaxis": "x", "y": [3.451963454669945, 7.4073296597234775, 7.4073296597234775, 5.396972119062367], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(0,116,217)"}, "mode": "lines", "type": "scatter", "x": [55.0, 55.0, 65.0, 65.0], "xaxis": "x", "y": [0.0, 2.4309588774276705, 2.4309588774276705, 0.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(0,116,217)"}, "mode": "lines", "type": "scatter", "x": [85.0, 85.0, 95.0, 95.0], "xaxis": "x", "y": [0.0, 3.2628513687160994, 3.2628513687160994, 0.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(0,116,217)"}, "mode": "lines", "type": "scatter", "x": [75.0, 75.0, 90.0, 90.0], "xaxis": "x", "y": [0.0, 3.9161622614357148, 3.9161622614357148, 3.2628513687160994], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(0,116,217)"}, "mode": "lines", "type": "scatter", "x": [60.0, 60.0, 82.5, 82.5], "xaxis": "x", "y": [2.4309588774276705, 7.03155386595107, 7.03155386595107, 3.9161622614357148], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(0,116,217)"}, "mode": "lines", "type": "scatter", "x": [45.0, 45.0, 71.25, 71.25], "xaxis": "x", "y": [0.0, 9.226303978681496, 9.226303978681496, 7.03155386595107], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(0,116,217)"}, "mode": "lines", "type": "scatter", "x": [20.0, 20.0, 58.125, 58.125], "xaxis": "x", "y": [7.4073296597234775, 17.48156430220074, 17.48156430220074, 9.226303978681496], "yaxis": "y"}],                        {"autosize": false, "height": 500, "hovermode": "closest", "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.333333333 ...

# %% [markdown]
# The dendrogram is a summary of the distance matrix.It helps in determing the clusters.

# %%
# 10 Sun burst chart – multi level pie chart.

year10 = data_new.Year == 1999
data_10 = data_new[year10]

fig_10 = px.sunburst(data_10, path=['Country_Name','Merchandise_imports_by_the_reporting_economy__residual__p_of_total_merchandise_imports_','Merchandise_imports__current_USp_'], values='Merchandise_exports_by_the_reporting_economy__residual__p_of_total_merchandise_exports_',width=700,height=700,title='In 1999')
fig_10.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="24e89d7b-dbfb-490a-9c14-378bfd319172" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24e89d7b-dbfb-490a-9c14-378bfd319172")) {                    Plotly.newPlot(                        "24e89d7b-dbfb-490a-9c14-378bfd319172",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Merchandise_exports_by_the_reporting_economy__residual__p_of_total_merchandise_exports_=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Samoa/1.03639934931238/115000000.0", "St. Kitts and Nevis/1.03063053623197/153000000.0", "Cabo Verde/1.48291493770527/246000000.0", "Suriname/6.476970517467179/486000000.0", "Liberia/2.78025590018011e-08/520000000.0", "Fiji/0.667020531603257/903000000.0", "Pacific island small states/1.59206967055641/1645996670.1359901", "Bahamas, The/1.72873736388876/1757000000.0", "Tunisia/1.9912130234049499/8474000000.0", "Czech Republic/1.87758002905091/28463293467.0", "Indonesia/0.68198400766276/33321000000.0", "Portugal/0.0831568624544629/39973528346.0", "Fragile and conflict affected situations/6.7357151981694505/44260476950.7351", "IDA only/8.292541829430139/57798260302.63901", "Liberia/2.78025590018011e-08", "Portugal/0.0831568624544629", "Fiji/0.667020531603257", "Indonesia/0.68198400766276", "St. Kitts and Nevis/1.03063053623197", "Samoa/1.03639934931238", "Cabo Verde/1.48291493770527", "Pacific island small states/1.59206967055641", "Bahamas, The/1.72873736388876", "Czech Republic/1.87758002905091", "Tunisia/1.9912130234049499", "Suriname/6.476970517467179", "Fragile and conflict affected situations/6.7357151981694505", "IDA only/8.292541829430139", "Bahamas, The", "Cabo Verde", "Czech Republic", "Fiji", "Fragile and conflict affected situations", "IDA only", "Indonesia", "Liberia", "Pacific island small states", "Portugal", "Samoa", "St. Kitts and Nevis", "Suriname", "Tunisia"], "labels": ["115000000.0", "153000000.0", "246000000.0", "486000000.0", "520000000.0", "903000000.0", "1645996670.1359901", "1757000000.0", "8474000000.0", "28463293467.0", "33321000000.0", "39973528346.0", "44260476950.7351", "57798260302.63901", "2.78025590018011e-08", "0.0831568624544629", "0.667020531603257", "0.68198400766276", "1.03063053623197", "1.03639934931238", "1.48291493770527", "1.59206967055641", "1.72873736388876", "1.87758002905091", "1.9912130234049499", "6.476970517467179", "6.7357151981694505", "8.292541829430139", "Bahamas, The", "Cabo Verde", "Czech Republic", "Fiji", "Fragile and conflict affected situations", "IDA only", "Indonesia", "Liberia", "Pacific island small states", "Portugal", "Samoa", "St. Kitts and Nevis", "Suriname", "Tunisia"], "name": "", "parents": ["Samoa/1.03639934931238", "St. Kitts and Nevis/1.03063053623197", "Cabo Verde/1.48291493770527", "Suriname/6.476970517467179", "Liberia/2.78025590018011e-08", "Fiji/0.667020531603257", "Pacific island small states/1.59206967055641", "Bahamas, The/1.72873736388876", "Tunisia/1.9912130234049499", "Czech Republic/1.87758002905091", "Indonesia/0.68198400766276", "Portugal/0.0831568624544629", "Fragile and conflict affected situations/6.7357151981694505", "IDA only/8.292541829430139", "Liberia", "Portugal", "Fiji", "Indonesia", "St. Kitts and Nevis", "Samoa", "Cabo Verde", "Pacific island small states", "Bahamas, The", "Czech Republic", "Tunisia", "Suriname", "Fragile and conflict affected situations", "IDA only", "", "", "", "", "", "", "", "", "", "", "", "", "", ""], "type": "sunburst", "values": [5.82062953185563, 2.80935928788417, 0.176975912898996, 0.7549408276014309, 0.0, 9.36440058265358, 7.65745119814984, 0.23516329086838397, 4.353670047662201, 0.41524306501309, 0.0547286 ...

# %% [markdown]
# ####**Observations:**
# From the above Sun burst chart we can say that Fiji islands has a growing economy (due to the boom in garment and a steady growth rate in the sugar industry). In a similar fashion we can say Portugal doesn't seem to have a growing economy. In this manner using the parameters we can compare the growth of economies of different countries in the year 1999.

# %% [markdown]
# ####**Summary**
# A summary of the entire analysis:
# 1. Import and export plays an important role in determining and contributing to the economy of a country.
# 2. Import and export values are determined by the supply and demand for different countries, means of transporting these goods and various other parameters.
# 3. Growth of an economy can be measured by export value index. If the value is stagnant for long periods of time it indicates prolonged or no growth in the economy.
# 4. Countries having good economies are those that have high export percentages in comparison to import percentages. If the import percentages of a country is less it suggests that the country is self sufficient and has a good percentage of resources to sustain.
# 5. Countries like China, US, France and Germany are huge exporters.
